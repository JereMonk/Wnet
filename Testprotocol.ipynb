# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

# %%
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt
import time
import h5py
import PIL
import pandas as pd
from tensorflow.keras.layers import *
from tensorflow.keras.layers import Dense,MaxPool2D,Conv2D,Conv2DTranspose,Conv2D,Conv2DTranspose,BatchNormalization,Input,ReLU,Add,Lambda,LeakyReLU,Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow import Tensor
from tensorflow.keras.models import load_model

import tensorflow as tf
from tensorflow.keras.utils import Sequence
import random
from importlib import reload 
from monk import Dataset
   
from PIL import Image 
import PIL

# %%
! python trainWnet.py '/home/ubuntu/trainings/damages_classification/2021-06-15-Wnet' 0
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# 2021-06-16 07:38:02.440565: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /home/ubuntu/trainings/damages_classification/2021-06-15-Wnet
# Importing from COCO JSON: 100%|██████████| 11876/11876 [00:13<00:00, 858.57it/s]
# 2021-06-16 07:38:36.859842: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-16 07:38:36.885818: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:36.886345: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-16 07:38:36.886407: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-16 07:38:36.890531: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-06-16 07:38:36.892595: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-06-16 07:38:36.892923: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-06-16 07:38:36.895360: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-06-16 07:38:36.896892: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-06-16 07:38:36.901930: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-06-16 07:38:36.902108: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:36.904007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:36.904470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-06-16 07:38:36.904745: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-16 07:38:36.912235: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2500000000 Hz
# 2021-06-16 07:38:36.912589: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56118303a610 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-06-16 07:38:36.912610: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-06-16 07:38:37.015239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:37.015850: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561183efdc40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-06-16 07:38:37.015885: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2021-06-16 07:38:37.016190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:37.016705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-16 07:38:37.016791: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-16 07:38:37.016822: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-06-16 07:38:37.016846: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2021-06-16 07:38:37.016867: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2021-06-16 07:38:37.016889: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2021-06-16 07:38:37.016910: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2021-06-16 07:38:37.016932: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2021-06-16 07:38:37.017030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:37.017566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:37.018038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2021-06-16 07:38:37.018116: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-16 07:38:37.507032: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-16 07:38:37.507082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2021-06-16 07:38:37.507097: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2021-06-16 07:38:37.507379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:37.507980: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-16 07:38:37.508468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10951 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5)
#
# Start of iter 0
# Learning rate<tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.03>
# WARNING:tensorflow:From /shared/perso/jeremy/projects/pricing/Wnet/ncut_loss.py:188: setdiff1d (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# This op will be removed after the deprecation date. Please switch to tf.sets.difference().
# 2021-06-16 07:38:51.398750: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2021-06-16 07:38:51.579155: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# step 0
# TRAIN LOSS ENCODER :  13.999989
# TRAIN LOSS DECODER :  0.011008985
# step 1
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0029777482
# step 2
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.000111821704
# step 3
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0011716629
# step 4
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  4.8210357e-05
# step 5
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  9.949245e-05
# step 6
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0013269625
# step 7
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0011674257
# step 8
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0002072007
# step 9
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0026328163
# step 10
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0033358454
# step 11
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.2933611e-05
# step 12
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00017208284
# step 13
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.001772002
# step 14
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.410982e-06
# step 15
# TRAIN LOSS ENCODER :  13.999937
# TRAIN LOSS DECODER :  0.059382595
# step 16
# TRAIN LOSS ENCODER :  13.9999895
# TRAIN LOSS DECODER :  0.009322757
# step 17
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00034407972
# step 18
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.008236136
# step 19
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0004756715
# step 20
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.7508597e-05
# step 21
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.4108238e-05
# step 22
# TRAIN LOSS ENCODER :  13.9999895
# TRAIN LOSS DECODER :  0.009106479
# step 23
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0030255525
# step 24
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0007497664
# step 25
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0010786813
# step 26
# TRAIN LOSS ENCODER :  13.9999275
# TRAIN LOSS DECODER :  0.12677708
# step 27
# TRAIN LOSS ENCODER :  13.999973
# TRAIN LOSS DECODER :  0.03567352
# step 28
# TRAIN LOSS ENCODER :  13.999986
# TRAIN LOSS DECODER :  0.014201334
# step 29
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.009636835
# step 30
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.4950686e-05
# step 31
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0036075946
# step 32
# TRAIN LOSS ENCODER :  13.999977
# TRAIN LOSS DECODER :  0.021896834
# step 33
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  5.107979e-05
# step 34
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0003166016
# step 35
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0021346633
# step 36
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0031053198
# step 37
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.000967973
# step 38
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0010465772
# step 39
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  5.174008e-06
# step 40
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.4913297e-05
# step 41
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00010617146
# step 42
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.4053697e-05
# step 43
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0008809259
# step 44
# TRAIN LOSS ENCODER :  13.999878
# TRAIN LOSS DECODER :  0.117549606
# step 45
# TRAIN LOSS ENCODER :  13.999984
# TRAIN LOSS DECODER :  0.014365406
# step 46
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.4345983e-05
# step 47
# TRAIN LOSS ENCODER :  13.99999
# TRAIN LOSS DECODER :  0.008654467
# step 48
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0002626591
# step 49
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00074490847
# step 50
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.001535464
# step 51
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0005451416
# step 52
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  9.197276e-05
# step 53
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.001709288
# step 54
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00025182278
# step 55
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.8617626e-05
# step 56
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00010855027
# step 57
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0020722675
# step 58
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0018320574
# step 59
# TRAIN LOSS ENCODER :  13.999951
# TRAIN LOSS DECODER :  0.04267154
# step 60
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.5191515e-05
# step 61
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00089047314
# step 62
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0008314755
# step 63
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.7611197e-05
# step 64
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00039949064
# step 65
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.4058456e-05
# step 66
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.2734664e-05
# step 67
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0051483028
# step 68
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.1856571e-05
# step 69
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0014865453
# step 70
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0016668746
# step 71
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.111271e-06
# step 72
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0014465278
# step 73
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0007584267
# step 74
# TRAIN LOSS ENCODER :  13.999895
# TRAIN LOSS DECODER :  0.060105965
# step 75
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.073711e-05
# step 76
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0030197161
# step 77
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.2618267e-05
# step 78
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0028442987
# step 79
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.000631102
# step 80
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0014147784
# step 81
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.00677037
# step 82
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0005052414
# step 83
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00079273316
# step 84
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00040070136
# step 85
# TRAIN LOSS ENCODER :  13.999983
# TRAIN LOSS DECODER :  0.015327284
# step 86
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0012112282
# step 87
# TRAIN LOSS ENCODER :  13.99999
# TRAIN LOSS DECODER :  0.012694314
# step 88
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00046956106
# step 89
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0008345492
# step 90
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.416632e-05
# step 91
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0001657212
# step 92
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0001649618
# step 93
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.008365869
# step 94
# TRAIN LOSS ENCODER :  13.999982
# TRAIN LOSS DECODER :  0.016964179
# step 95
# TRAIN LOSS ENCODER :  13.999994
# TRAIN LOSS DECODER :  0.004579558
# step 96
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00043788654
# step 97
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.00623868
# step 98
# TRAIN LOSS ENCODER :  13.999994
# TRAIN LOSS DECODER :  0.004794811
# step 99
# TRAIN LOSS ENCODER :  13.999986
# TRAIN LOSS DECODER :  0.01832851
# step 100
# TRAIN LOSS ENCODER :  13.999994
# TRAIN LOSS DECODER :  0.0040295916
# step 101
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00047129302
# step 102
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0013202054
# step 103
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00010534586
# step 104
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0046293023
# step 105
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.8461108e-06
# step 106
# TRAIN LOSS ENCODER :  13.9999695
# TRAIN LOSS DECODER :  0.011469172
# step 107
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0002695456
# step 108
# TRAIN LOSS ENCODER :  13.999784
# TRAIN LOSS DECODER :  0.4088912
# step 109
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0004147439
# step 110
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0005824155
# step 111
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0012431194
# step 112
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0003085084
# step 113
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.002900922
# step 114
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.002067951
# step 115
# TRAIN LOSS ENCODER :  13.999991
# TRAIN LOSS DECODER :  0.009780638
# step 116
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00065032963
# step 117
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00041266094
# step 118
# TRAIN LOSS ENCODER :  13.999987
# TRAIN LOSS DECODER :  0.010389198
# step 119
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0017945141
# step 120
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00015312867
# step 121
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0009524472
# step 122
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.0059563434
# step 123
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00072292663
# step 124
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00011582079
# step 125
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00010582141
# step 126
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00011735295
# step 127
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.857836e-05
# step 128
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00012272756
# step 129
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0014607743
# step 130
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00020858314
# step 131
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0010536329
# step 132
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0029061101
# step 133
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.002293992
# step 134
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  4.541677e-05
# step 135
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.234928e-05
# step 136
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.8374063e-05
# step 137
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0007761146
# step 138
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0056081647
# step 139
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.8995446e-05
# step 140
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00022622102
# step 141
# TRAIN LOSS ENCODER :  13.999994
# TRAIN LOSS DECODER :  0.0057294974
# step 142
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00067729136
# step 143
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.7783466e-05
# step 144
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.6446542e-05
# step 145
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.5218719e-05
# step 146
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0042142193
# step 147
# TRAIN LOSS ENCODER :  13.99999
# TRAIN LOSS DECODER :  0.01016474
# step 148
# TRAIN LOSS ENCODER :  13.999988
# TRAIN LOSS DECODER :  0.015225217
# step 149
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  9.244939e-06
# step 150
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00039603055
# step 151
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00010877782
# step 152
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00092579285
# step 153
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.722178e-05
# step 154
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00051429914
# step 155
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0003122093
# step 156
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00014775894
# step 157
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0016200384
# step 158
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.9279766e-06
# step 159
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.7065201e-06
# step 160
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.3931614e-05
# step 161
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.48788e-05
# step 162
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.3360164e-05
# step 163
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.00887308
# step 164
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.324663e-05
# step 165
# TRAIN LOSS ENCODER :  13.999774
# TRAIN LOSS DECODER :  0.25131327
# step 166
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0025790955
# step 167
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00012202737
# step 168
# TRAIN LOSS ENCODER :  13.999996
# TRAIN LOSS DECODER :  0.004691339
# step 169
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0032350626
# step 170
# TRAIN LOSS ENCODER :  13.999996
# TRAIN LOSS DECODER :  0.0047685616
# step 171
# TRAIN LOSS ENCODER :  13.999983
# TRAIN LOSS DECODER :  0.018819273
# step 172
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0003348954
# step 173
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.0670696e-05
# step 174
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  5.5500925e-05
# step 175
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00015288053
# step 176
# TRAIN LOSS ENCODER :  13.999874
# TRAIN LOSS DECODER :  0.07117218
# step 177
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00045727022
# step 178
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0001426274
# step 179
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.006678936
# step 180
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.000197444
# step 181
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00010044896
# step 182
# TRAIN LOSS ENCODER :  13.999993
# TRAIN LOSS DECODER :  0.0053812386
# step 183
# TRAIN LOSS ENCODER :  13.999992
# TRAIN LOSS DECODER :  0.005343356
# step 184
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.676112e-05
# step 185
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0023413124
# step 186
# TRAIN LOSS ENCODER :  13.999959
# TRAIN LOSS DECODER :  0.042172644
# step 187
# TRAIN LOSS ENCODER :  13.999996
# TRAIN LOSS DECODER :  0.0055728983
# step 188
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.7872757e-05
# step 189
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0010804458
# step 190
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0005561493
# step 191
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0004835421
# step 192
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.017243e-05
# step 193
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  9.851338e-05
# step 194
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.7728604e-05
# step 195
# TRAIN LOSS ENCODER :  13.999994
# TRAIN LOSS DECODER :  0.0049235895
# step 196
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.4384443e-05
# step 197
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  1.3201443e-05
# step 198
# TRAIN LOSS ENCODER :  13.99999
# TRAIN LOSS DECODER :  0.0114182355
# step 199
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.416493e-06
# step 200
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.788707e-06
# step 201
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0011239976
# step 202
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0014569473
# step 203
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  2.6586893e-05
# step 204
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0011691913
# step 205
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0004949798
# step 206
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0019240605
# step 207
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0015654701
# step 208
# TRAIN LOSS ENCODER :  13.9999695
# TRAIN LOSS DECODER :  0.011472542
# step 209
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.649453e-06
# step 210
# TRAIN LOSS ENCODER :  13.999981
# TRAIN LOSS DECODER :  0.01984996
# step 211
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00014635139
# step 212
# TRAIN LOSS ENCODER :  13.99999
# TRAIN LOSS DECODER :  0.008956615
# step 213
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0001089902
# step 214
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00014945658
# step 215
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.00071591756
# step 216
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0036232914
# step 217
# TRAIN LOSS ENCODER :  13.999972
# TRAIN LOSS DECODER :  0.029845756
# step 218
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0058859508
# step 219
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  5.01552e-05
# step 220
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.666529e-06
# step 221
# TRAIN LOSS ENCODER :  13.999995
# TRAIN LOSS DECODER :  0.0051779975
# step 222
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.0922897e-06
# step 223
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.0030037058
# step 224
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.2334066e-06
# step 225
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.002267635
# step 226
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  6.513569e-05
# step 227
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.000571436
# step 228
# TRAIN LOSS ENCODER :  13.999946
# TRAIN LOSS DECODER :  0.057485268
# step 229
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0019486861
# step 230
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  9.472456e-06
# step 231
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.736044e-06
# step 232
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.071065e-06
# step 233
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0011421015
# step 234
# TRAIN LOSS ENCODER :  13.999996
# TRAIN LOSS DECODER :  0.003262535
# step 235
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.00017007372
# step 236
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.002049777
# step 237
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.742872e-05
# step 238
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  5.9679555e-06
# step 239
# TRAIN LOSS ENCODER :  13.999986
# TRAIN LOSS DECODER :  0.012851037
# step 240
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0004936801
# step 241
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  8.545646e-05
# step 242
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  0.0006540164
# step 243
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  4.4223987e-05
# step 244
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  3.1136544e-06
# step 245
# TRAIN LOSS ENCODER :  13.999998
# TRAIN LOSS DECODER :  0.0012222852
# step 246
# TRAIN LOSS ENCODER :  13.999933
# TRAIN LOSS DECODER :  0.02777748
# step 247
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0009859196
# step 248
# TRAIN LOSS ENCODER :  13.999997
# TRAIN LOSS DECODER :  0.002820723
# step 249
# TRAIN LOSS ENCODER :  14.0
# TRAIN LOSS DECODER :  7.239777e-06
# step 250
# TRAIN LOSS ENCODER :  13.999999
# TRAIN LOSS DECODER :  0.0006780314
# ^C
# Traceback (most recent call last):
#   File "trainWnet.py", line 61, in <module>
#     main(sys.argv[1:])
#   File "trainWnet.py", line 55, in main
#     training(model=wn,train_dataset=generator_train,test_dataset=generator_test,max_iter=MAX_ITER,start_iter=START_ITER,base_lr=BASE_LR,ckpt_freq=CHECKPOINT_PERIOD,img_freq=IMG_PERIOD,dir_path=EXP_FOLDER,solver_steps=STEPS,test_freq=TEST_PERIOD)
#   File "/shared/perso/jeremy/projects/pricing/Wnet/trainer.py", line 41, in training
#     for step, x_batch_train in enumerate(train_dataset):
#   File "/home/ubuntu/anaconda3/envs/jeremy/lib/python3.8/site-packages/tensorflow/python/keras/utils/data_utils.py", line 486, in __iter__
#     for item in (self[i] for i in range(len(self))):
#   File "/home/ubuntu/anaconda3/envs/jeremy/lib/python3.8/site-packages/tensorflow/python/keras/utils/data_utils.py", line 486, in <genexpr>
#     for item in (self[i] for i in range(len(self))):
#   File "/shared/perso/jeremy/projects/pricing/Wnet/getData.py", line 74, in __getitem__
#     X = self.__data_generation(list_IDs_temp)
#   File "/shared/perso/jeremy/projects/pricing/Wnet/getData.py", line 94, in __data_generation
#     X[i,] = self.load_image(self.map_id[ID])
#   File "/shared/perso/jeremy/projects/pricing/Wnet/getData.py", line 56, in load_image
#     img_crop = imds.image.crop(my_to_bbox(ann)).resize(self.dim)
#   File "/home/ubuntu/anaconda3/envs/jeremy/lib/python3.8/functools.py", line 967, in __get__
#     val = self.func(instance)
#   File "/shared/perso/jeremy/libs/monk/monk/structures/images.py", line 122, in image
#     return self.get_image()
#   File "/shared/perso/jeremy/libs/monk/monk/structures/images.py", line 125, in get_image
#     return read_from_pil(self.pil)
#   File "/shared/perso/jeremy/libs/monk/monk/structures/images.py", line 297, in read_from_pil
#     return Image(rgb=np.asarray(pil_image), exif_rot=rot)
#   File "/shared/perso/jeremy/libs/monk/monk/structures/images.py", line 232, in __init__
#     raise ValueError("Image dtype must be uint8")
# ValueError: Image dtype must be uint8

# %%
l = ["ckpt9000.ckpt","ckpt1000.ckpt","ckpt8000.ckpt",'log.events']

# %%
ckpts=[]
for file in l:
    if file.endswith('ckpt'):
        ckpts.append(file)

    
print(ckpts)
# Out:
# ['ckpt9000.ckpt', 'ckpt1000.ckpt', 'ckpt8000.ckpt']

# %%
sorted_list = sorted(ckpts)
print(sorted_list)
# Out:
# ['ckpt1000.ckpt', 'ckpt8000.ckpt', 'ckpt9000.ckpt']

# %%
ck = sorted_list[-1]

# %%
int(ck.replace('.ckpt','').replace('ckpt',''))
# Out:
# 9000
